# %%
# import modules
import os
import pandas as pd

# %%
cityData = pd.read_csv('Resources/cities.csv')
cityData.head()
# Out:
#    Unnamed: 0              City      Lat       Lng  Max Temp  Humidity  \
# 0           0           Aklavik  68.2191 -135.0107     64.58      66.0
# 1           1           Paamiut  61.9940  -49.6678     41.77      88.0
# 2           2        Ust-Tsilma  65.4410   52.1498     53.98      75.0
# 3           3          viligili      NaN       NaN       NaN       NaN
# 4           4  illoqqortoormiut      NaN       NaN       NaN       NaN
#
#    Cloudiness  Wind Speed Country          Date
# 0       100.0        4.36      CA  1.660790e+09
# 1        17.0       12.30      GL  1.660790e+09
# 2        24.0        4.79      RU  1.660790e+09
# 3         NaN         NaN     NaN           NaN
# 4         NaN         NaN     NaN           NaN

# %%
cityData.to_html('tableData.html', index=False, classes=['table', 'table-striped', 'table-hover'])
